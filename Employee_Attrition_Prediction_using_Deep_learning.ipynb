# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('employee_attrition.csv')
df.head()
# Out:
#    EmployeeID   Age  Gender Country   Department JobLevel  YearsAtCompany  \
# 0           1  50.0  Female      UK  Development   Junior              19
# 1           2  36.0   Other      UK      Support      Mid               4
# 2           3  29.0    Male     USA        Sales      Mid               4
# 3           4  42.0    Male  Canada    Marketing   Senior               3
# 4           5  40.0  Female      UK      Support   Junior              17
#
#    MonthlyIncome  NumProjects  LastEvaluationScore  SatisfactionLevel  \
# 0       124815.0            7                 0.44                  2
# 1        49908.0            6                 0.76                  2
# 2       115651.0            9                 0.81                  4
# 3        36728.0            8                 0.66                  1
# 4        37855.0            9                 0.89                  2
#
#    AvgWorkHoursPerWeek  PromotedLast5Years  HasMentor  RemoteWork  \
# 0                   54                   1          1           1
# 1                   52                   0          0           1
# 2                   43                   0          1           0
# 3                   57                   1          1           1
# 4                   41                   1          1           0
#
#    TrainingHours  Certifications  LeavesTaken  FeedbackScore  Attrition
# 0              9               3           21            4.4          0
# 1             67               1            5            1.4          0
# 2             98               0            3            4.3          0
# 3             14               0           18            4.7          1
# 4             58               0           21            1.8          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35000 entries, 0 to 34999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           35000 non-null  int64
#  1   Age                  33950 non-null  float64
#  2   Gender               35000 non-null  object
#  3   Country              35000 non-null  object
#  4   Department           35000 non-null  object
#  5   JobLevel             35000 non-null  object
#  6   YearsAtCompany       35000 non-null  int64
#  7   MonthlyIncome        33950 non-null  float64
#  8   NumProjects          35000 non-null  int64
#  9   LastEvaluationScore  33950 non-null  float64
#  10  SatisfactionLevel    35000 non-null  int64
#  11  AvgWorkHoursPerWeek  35000 non-null  int64
#  12  PromotedLast5Years   35000 non-null  int64
#  13  HasMentor            35000 non-null  int64
#  14  RemoteWork           35000 non-null  int64
#  15  TrainingHours        35000 non-null  int64
#  16  Certifications       35000 non-null  int64
#  17  LeavesTaken          35000 non-null  int64
#  18  FeedbackScore        35000 non-null  float64
#  19  Attrition            35000 non-null  int64
# dtypes: float64(4), int64(12), object(4)
# memory usage: 5.3+ MB

# %%
df.isnull().sum()
# Out:
# EmployeeID                0
# Age                    1050
# Gender                    0
# Country                   0
# Department                0
# JobLevel                  0
# YearsAtCompany            0
# MonthlyIncome          1050
# NumProjects               0
# LastEvaluationScore    1050
# SatisfactionLevel         0
# AvgWorkHoursPerWeek       0
# PromotedLast5Years        0
# HasMentor                 0
# RemoteWork                0
# TrainingHours             0
# Certifications            0
# LeavesTaken               0
# FeedbackScore             0
# Attrition                 0
# dtype: int64

# %%
print(df['LastEvaluationScore'].mean())
print(df['LastEvaluationScore'].median())
print(df['LastEvaluationScore'].mode())
# Out:
# 0.7009935198821797
# 0.7
# 0    0.68
# Name: LastEvaluationScore, dtype: float64

# %%
for col in ['Age','MonthlyIncome','LastEvaluationScore']:
    df[col]=df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# EmployeeID             0
# Age                    0
# Gender                 0
# Country                0
# Department             0
# JobLevel               0
# YearsAtCompany         0
# MonthlyIncome          0
# NumProjects            0
# LastEvaluationScore    0
# SatisfactionLevel      0
# AvgWorkHoursPerWeek    0
# PromotedLast5Years     0
# HasMentor              0
# RemoteWork             0
# TrainingHours          0
# Certifications         0
# LeavesTaken            0
# FeedbackScore          0
# Attrition              0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
df['Attrition'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Attrition')
plt.show()

# %%
sns.countplot(x='JobLevel',hue='Attrition',data=df)
plt.title('Attrition by Job Level')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Attrition',y='AvgWorkHoursPerWeek',data=df)
plt.title('Average Work Hours by Attrition')
plt.show()

# %%
plt.figure(figsize=(6,4))
country_churn=df.groupby('Country')['Attrition'].mean().sort_values()
country_churn.plot(kind='bar',color='teal')
plt.title('Attrition Rate by Country')
plt.xlabel('Country')
plt.ylabel('Attrition Rate')
plt.show()

# %%
df['Age'].hist(bins=30)
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='LastEvaluationScore',hue='Attrition',multiple='stack',bins=30,kde=True)
plt.title('Last Evaluation Score Distribution by Attrition')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categorical_label=['Gender','Country','Department','JobLevel']
df[categorical_label]=df[categorical_label].apply(LabelEncoder().fit_transform)

# %%
df.drop('EmployeeID',inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35000 entries, 0 to 34999
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  35000 non-null  float64
#  1   Gender               35000 non-null  int32
#  2   Country              35000 non-null  int32
#  3   Department           35000 non-null  int32
#  4   JobLevel             35000 non-null  int32
#  5   YearsAtCompany       35000 non-null  int64
#  6   MonthlyIncome        35000 non-null  float64
#  7   NumProjects          35000 non-null  int64
#  8   LastEvaluationScore  35000 non-null  float64
#  9   SatisfactionLevel    35000 non-null  int64
#  10  AvgWorkHoursPerWeek  35000 non-null  int64
#  11  PromotedLast5Years   35000 non-null  int64
#  12  HasMentor            35000 non-null  int64
#  13  RemoteWork           35000 non-null  int64
#  14  TrainingHours        35000 non-null  int64
#  15  Certifications       35000 non-null  int64
#  16  LeavesTaken          35000 non-null  int64
#  17  FeedbackScore        35000 non-null  float64
#  18  Attrition            35000 non-null  int64
# dtypes: float64(4), int32(4), int64(11)
# memory usage: 4.5 MB

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('Attrition',axis=1)
y=df['Attrition']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len(x_train),len(x_test)
# Out:
# (28000, 7000)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaled=scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)
X_train_scaled_df=pd.DataFrame(x_train_scaled,columns=x_train.columns,index=x_train.index)
X_test_scaled_df=pd.DataFrame(x_test_scaled,columns=x_test.columns,index=x_test.index)

# %%
import tensorflow as tf

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Dense(64,activation='relu',input_shape=(X_train_scaled_df.shape[1],)),
    tf.keras.layers.Dense(32,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(X_train_scaled_df,y_train,epochs=10,validation_split=0.2,batch_size=32)
# Out:
# Epoch 1/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7720 - loss: 0.5454 - val_accuracy: 0.7829 - val_loss: 0.5350
# Epoch 2/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7813 - loss: 0.5263 - val_accuracy: 0.7829 - val_loss: 0.5296
# Epoch 3/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7796 - loss: 0.5248 - val_accuracy: 0.7829 - val_loss: 0.5282
# Epoch 4/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7763 - loss: 0.5267 - val_accuracy: 0.7829 - val_loss: 0.5311
# Epoch 5/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7777 - loss: 0.5226 - val_accuracy: 0.7829 - val_loss: 0.5313
# Epoch 6/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7766 - loss: 0.5217 - val_accuracy: 0.7829 - val_loss: 0.5338
# Epoch 7/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7796 - loss: 0.5167 - val_accuracy: 0.7829 - val_loss: 0.5312
# Epoch 8/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7800 - loss: 0.5147 - val_accuracy: 0.7829 - val_loss: 0.5324
# Epoch 9/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7753 - loss: 0.5174 - val_accuracy: 0.7825 - val_loss: 0.5364
# Epoch 10/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7779 - loss: 0.5086 - val_accuracy: 0.7823 - val_loss: 0.5352

# %%
loss,acc=model.evaluate(X_test_scaled_df,y_test)
print(f'Accuracy Score: {acc*100:.2f}%')
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7734 - loss: 0.5424
# Accuracy Score: 77.99%

# %%
from sklearn.metrics import confusion_matrix,classification_report,ConfusionMatrixDisplay

# %%
plt.plot(history.history['accuracy'],label='Train')
plt.plot(history.history['val_accuracy'],label='Test')
plt.title('Model Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len(x_train),len(x_test)
# Out:
# (28000, 7000)

# %%
ypred=(model.predict(x_test)>0.5).astype(int)
cm=confusion_matrix(y_test,ypred)
ConfusionMatrixDisplay(cm).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
